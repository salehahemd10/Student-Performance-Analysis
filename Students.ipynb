# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv") 
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape[0]
# Out:
# 1000

# %%
df.shape[1]
# Out:
# 8

# %%
df.gender.value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df["parental level of education"].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
df.lunch.value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
df[["test preparation course"]].value_counts()
# Out:
# test preparation course
# none                       642
# completed                  358
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
pd.crosstab(df.gender , df["race/ethnicity"])
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female               36      104      180      129       69
# male                 53       86      139      133       71

# %%
len(df["race/ethnicity"].value_counts())
# Out:
# 5

# %%
pd.crosstab(df.gender , df["parental level of education"])
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# gender
# female                                      116                 63
# male                                        106                 55
#
# parental level of education  high school  master's degree  some college  \
# gender
# female                                94               36           118
# male                                 102               23           108
#
# parental level of education  some high school
# gender
# female                                     91
# male                                       88

# %%
pd.crosstab( df["parental level of education"],df.gender).plot (kind = "bar")
# Out:
# <Axes: xlabel='parental level of education'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby("gender").sum(numeric_only=True)[["reading score"]]
# Out:
#         reading score
# gender
# female          37611
# male            31558

# %%
df.groupby("gender").sum(numeric_only=True)
# Out:
#         math score  reading score  writing score
# gender
# female       32962          37611          37538
# male         33127          31558          30516

# %%
df.groupby("gender").mean(numeric_only=True)[["reading score"]]
# Out:
#         reading score
# gender
# female      72.608108
# male        65.473029

# %%
df.groupby("gender").mean(numeric_only=True)[["writing score"]]
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.groupby(["race/ethnicity"]).mean(numeric_only=True).plot(kind = "bar")
# Out:
# <Axes: xlabel='race/ethnicity'>

# %%
df.groupby(["race/ethnicity"]).mean(numeric_only=True)
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %%
df.groupby("race/ethnicity").mean(numeric_only=True)[["math score"]].plot(kind="bar")
# Out:
# <Axes: xlabel='race/ethnicity'>

# %%
pd.crosstab(df.gender , df["race/ethnicity"]).plot(kind = "line")
# Out:
# <Axes: xlabel='gender'>

# %%
pd.crosstab(df["race/ethnicity"] ,df.lunch )
# Out:
# lunch           free/reduced  standard
# race/ethnicity
# group A                   36        53
# group B                   69       121
# group C                  114       205
# group D                   95       167
# group E                   41        99

# %%
df.groupby("race/ethnicity").mean(numeric_only=True)
# Out:
#                 math score  reading score  writing score
# race/ethnicity
# group A          61.629213      64.674157      62.674157
# group B          63.452632      67.352632      65.600000
# group C          64.463950      69.103448      67.827586
# group D          67.362595      70.030534      70.145038
# group E          73.821429      73.028571      71.407143

# %%
        pd.crosstab([df.gender , df["parental level of education"]] , df["race/ethnicity"] , values= df["reading score"] ,aggfunc="sum")
# Out:
# race/ethnicity                      group A  group B  group C  group D  \
# gender parental level of education
# female associate's degree               421     1660     3324     1751
#        bachelor's degree                180      880     2012     1014
#        high school                      489     1933     1979     1168
#        master's degree                  120      428      521     1124
#        some college                     566     1035     3213     2671
#        some high school                 708     1456     1901     1824
# male   associate's degree               518     1193     2224     1776
#        bachelor's degree                637      579     1015      950
#        high school                      643     1113     2144     1666
#        master's degree                   74       53      819      651
#        some college                     618     1398     1577     2078
#        some high school                 782     1069     1315     1675
#
# ...

# %%
        pd.crosstab(df.gender , df["race/ethnicity"], values= df["writing score"] ,aggfunc="max")
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female               97       96      100      100      100
# male                 92       92       95       99      100

# %%
        pd.crosstab( df["race/ethnicity"],df.gender, values= df["writing score"] ,aggfunc="max").plot(kind="bar")
# Out:
# <Axes: xlabel='race/ethnicity'>

# %%
df.groupby("gender").mean(numeric_only=True)[["reading score"]]
# Out:
#         reading score
# gender
# female      72.608108
# male        65.473029

# %%
        pd.crosstab(df["parental level of education"] , df.gender,values= df["math score"] ,aggfunc="mean")
# Out:
# gender                          female       male
# parental level of education
# associate's degree           65.250000  70.764151
# bachelor's degree            68.349206  70.581818
# high school                  59.351064  64.705882
# master's degree              66.500000  74.826087
# some college                 65.406780  69.009259
# some high school             59.296703  67.840909

# %%
        pd.crosstab(df["parental level of education"] , df.gender,values= df["math score"] ,aggfunc="mean").plot(kind="bar")
# Out:
# <Axes: xlabel='parental level of education'>

# %%
df.groupby("gender").mean(numeric_only=True)[["writing score"]]
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
df.groupby("gender").mean(numeric_only=True)[["writing score"]].plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
        pd.crosstab([df.gender , df["parental level of education"]] , df["lunch"] , values= df["reading score"] ,aggfunc="mean")
# Out:
# lunch                               free/reduced   standard
# gender parental level of education
# female associate's degree              70.250000  75.862500
#        bachelor's degree               74.000000  79.048780
#        high school                     63.027027  71.561404
#        master's degree                 72.214286  79.727273
#        some college                    69.159091  76.162162
#        some high school                60.916667  74.472727
# male   associate's degree              65.365854  68.738462
#        bachelor's degree               63.863636  70.909091
#        high school                     57.060606  63.594203
#        master's degree                 67.600000  77.384615
#        some college                    59.942857  67.410959
#        some high school                58.960000  66.968254

# %%
        pd.crosstab([df.gender , df["parental level of education"]] , df["lunch"] , values= df["reading score"] ,aggfunc="mean").plot(kind="bar")
# Out:
# <Axes: xlabel='gender,parental level of education'>
